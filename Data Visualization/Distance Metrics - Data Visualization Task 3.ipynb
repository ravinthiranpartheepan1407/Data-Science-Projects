# %%
from pandas import Series

# %%
data = Series.from_csv('F:/Applied Informatics/Semester-III/Data Visualization/Laboratory Works/Homework 3/archive/DailyClimateTest.csv', header=0)

# %%
testing = data.head(10)

# %%
tested = data.tail

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
test = data['2017-03']

# %%
data.size
# Out:
# 114

# %%
data.describe
# Out:
# <bound method NDFrame.describe of date
# 2017-01-01    15.913043
# 2017-01-02    18.500000
# 2017-01-03    17.111111
# 2017-01-04    18.700000
# 2017-01-05    18.388889
# 2017-01-06    19.318182
# 2017-01-07    14.708333
# 2017-01-08    15.684211
# 2017-01-09    14.571429
# 2017-01-10    12.111111
# 2017-01-11    11.000000
# 2017-01-12    11.789474
# 2017-01-13    13.235294
# 2017-01-14    13.200000
# 2017-01-15    16.434783
# 2017-01-16    14.650000
# 2017-01-17    11.722222
# 2017-01-18    13.041667
# 2017-01-19    14.619048
# 2017-01-20    15.263158
# 2017-01-21    15.391304
# 2017-01-22    18.440000
# 2017-01-23    18.117647
# 2017-01-24    18.347826
# 2017-01-25    21.000000
# 2017-01-26    16.178571
# 2017-01-27    16.500000
# 2017-01-28    14.863636
# 2017-01-29    15.666667
# 2017-01-30    16.444444
#                 ...
# 2017-03-26    29.100000
# 2017-03-27    29.500000
# 2017-03-28    29.888889
# 2017-03-29    31.000000
# 2017-03-30    29.285714
# 2017-03-31    30.625000
# 2017-04-01    31.375000
# 2017-04-02    29.750000
# 2017-04-03    30.500000
# 2017-04-04    30.933333
# 2017-04-05    29.230769
# 2017-04-06    31.222222
# 2017-04-07    27.000000
# 2017-04-08    25.625000
# 2017-04-09    27.125000
# 2017-04-10    27.857143
# 2017-04-11    29.250000
# 2017-04-12    29.250000
# 2017-04-13    29.666667
# 2017-04-14    30.500000
# 2017-04-15    31.222222
# 2017-04-16    31.000000
# 2017-04-17    32.555556
# 2017-04-18    34.000000
# 2017-04-19    33.500000
# 2017-04-20    34.500000
# 2017-04-21    34.250000
# 2017-04-22    32.900000
# 2017-04-23    32.875000
# 2017-04-24    32.000000
# Name: meantemp, Length: 114, dtype: float64>

# %%
team = data.describe()

# %%
from matplotlib import pyplot as plt
plt.plot(test)
plt.figsize = (60,60)
plt.xlabel("March Month")
plt.ylabel("Temperature")
plt.show()

# %%
test_1 = data['2017-04']

# %%
test_1.describe()
# Out:
# count    24.000000
# mean     30.753663
# std       2.379940
# min      25.625000
# 25%      29.250000
# 50%      30.966667
# 75%      32.635417
# max      34.500000
# Name: meantemp, dtype: float64

# %%
plt.plot(test_1)
plt.figsize = (30,30)
plt.xlabel("April Month")
plt.ylabel("Temperature")
plt.show()

# %%
from scipy.spatial import distance

# %%
d = distance.euclidean(ravi,suren)
print("The euclidean distance between 2017/03/01 and 2017/04/01 is", d)
# Out:
# The euclidean distance between 2017/03/01 and 2017/04/01 is 20.325296351148207

# %%
data.head()
# Out:
# date
# 2017-01-01    15.913043
# 2017-01-02    18.500000
# 2017-01-03    17.111111
# 2017-01-04    18.700000
# 2017-01-05    18.388889
# Name: meantemp, dtype: float64

# %%
plt.plot(testing)
plt.figsize = (100,100)
plt.xlabel("Date")
plt.ylabel("Temperature")
plt.show()

# %%
from scipy.spatial import distance
dist = distance.cityblock(ravi,suren)
print("The Manhattan distance between 2017/03/01 and 2017/04/01 is ",dist)
# Out:
# The Manhattan distance between 2017/03/01 and 2017/04/01 is  44.2025641025641

# %%
ravi = test.head()

# %%
ravi.head()
# Out:
# date
# 2017-03-01    24.461538
# 2017-03-02    23.750000
# 2017-03-03    20.500000
# 2017-03-04    19.125000
# 2017-03-05    19.750000
# Name: meantemp, dtype: float64

# %%
suren = test_1.head()

# %%
suren.head()
# Out:
# date
# 2017-04-01    31.375000
# 2017-04-02    29.750000
# 2017-04-03    30.500000
# 2017-04-04    30.933333
# 2017-04-05    29.230769
# Name: meantemp, dtype: float64

# %%
dista = distance.cityblock(ravi,suren)

# %%
plt.plot(ravi)
plt.figsize = (40,40)
plt.title("Manhattan Distance")
plt.show()

# %%
plt.plot(suren)
plt.figsize = (40,40)
plt.title("Manhattan Distance")
plt.show()

# %%
import math
cos_sim = test_fail * test_Pass
cons_sim_1 = math.floor(math.sqrt(test_fail * test_fail))
cons_sim_2 = math.floor(math.sqrt(test_Pass * test_Pass))
consin_sim = cos_sim / (cons_sim_1) * (cons_sim_2)
print("The cosine similarity between 2017/03/01 and 2017/04/01 is ", consin_sim)
# Out:
# The cosine similarity between 2017/03/01 and 2017/04/01 is  529.0

# %%
import math
jacc = test_Pass
jacc_1 = test_fail + test_Pass
jacc_Ans = jacc / jacc_1
print("Jaccard similarity:", jacc_Ans)
# Out:
# Jaccard similarity: 0.6052631578947368

# %%
from math import *
print("Simple Matching Co-efficient")
distanc_1 = test_fail
distanc_2 = test_Pass
Simple_Mat = distanc_1 + distanc_2
Simple_Div = data
Simple_Ans = Simple_Mat / distanc_1 + distanc_2
print(Simple_Ans)
# Out:
# Simple Matching Co-efficient
# 25.53333333333333

# %%
test_fail = 15
test_Pass = 23

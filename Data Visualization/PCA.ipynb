# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
data = "F:/Applied Informatics/Semester-III/Data Visualization/Laboratory Works/Homework 6 and 7/Dataset/cars.csv"

# %%
data
# Out:
# 'F:/Applied Informatics/Semester-III/Data Visualization/Laboratory Works/Homework 6 and 7/Dataset/cars.csv'

# %%
dataf = pd.read_csv(data, names=['mpg','cylinders','cubicinches','hp','weightlbs','time-to-60','year','brand'])

# %%
dataf.head()
# Out:
#     mpg   cylinders   cubicinches   hp   weightlbs   time-to-60   year  \
# 0   mpg   cylinders   cubicinches   hp   weightlbs   time-to-60   year
# 1    14           8           350  165        4209           12   1972
# 2  31.9           4            89   71        1925           14   1980
# 3    17           8           302  140        3449           11   1971
# 4    15           8           400  150        3761           10   1971
#
#       brand
# 0     brand
# 1       US.
# 2   Europe.
# 3       US.
# 4       US.

# %%
features = ['mpg','cylinders','cubicinches','hp']
cars = dataf.loc[2:30, features].values

# %%
cars_y = dataf.loc[2:30,['brand']].values

# %%
carss = StandardScaler().fit_transform(cars)

# %%
pd.DataFrame(data = cars, columns = features).head(30)
# Out:
#      mpg cylinders cubicinches   hp
# 0   31.9         4          89   71
# 1     17         8         302  140
# 2     15         8         400  150
# 3   30.5         4          98   63
# 4     23         8         350  125
# 5     13         8         351  158
# 6     14         8         440  215
# 7   25.4         5         183   77
# 8   37.7         4          89   62
# 9     34         4         108   70
# 10  34.3         4          97   78
# 11    16         8         302  140
# 12    11         8         350  180
# 13  19.1         6         225   90
# 14  16.9         8         350  155
# 15  31.8         4          85   65
# 16    16         8         304  150
# 17    24         4         113   95
# 18    24         4         107   90
# 19  37.2         4          86   65
# 20  21.5         4         121  110
# 21    24         6         200   81
# 22  15.5         8         351  142
# 23  38.1         4          89   60
# 24    33         4          91   53
# 25    31         4          71   65
# 26    14         8         351  148
# 27    18         6         250   78
# 28  29.9         4          98   65

# %%
pca = PCA(n_components = 2)

# %%
principalComponents = pca.fit_transform(cars)

# %%
principalDf = pd.DataFrame(data = principalComponents, columns = ['PrincipalComponent_1','PrincipalComponent_2'])

# %%
principalDf.head(30)
# Out:
#     PrincipalComponent_1  PrincipalComponent_2
# 0            -124.482385             -5.695018
# 1              99.929554             -3.852403
# 2             196.000234             17.834188
# 3            -118.404550              4.662550
# 4             140.289507             25.996358
# 5             152.247166             -5.480252
# 6             254.462769            -30.950839
# 7             -33.183426             18.246173
# 8            -127.666225              3.154447
# 9            -106.931021              1.433536
# 10           -114.837865             -9.625730
# 11             99.988427             -3.910311
# 12            158.366053            -26.726087
# 13             11.076468             18.989279
# 14            150.123216             -2.735544
# 15           -130.158954             -1.301075
# 16            105.040391            -12.731866
# 17            -93.712377            -21.199432
# 18           -100.972784            -18.383652
# 19           -129.529986             -0.669372
# 20            -81.252822            -32.981536
# 21            -15.726514             19.811637
# 22            147.046872              9.799805
# 23           -128.321413              5.069521
# 24           -128.338124             12.033877
# 25           -143.368246             -5.813396
# 26            149.030099              4.037210
# 27             31.023524             38.252036
# 28           -117.737588              2.735895

# %%
dataf[['brand']].head(30)
# Out:
#        brand
# 0      brand
# 1        US.
# 2    Europe.
# 3        US.
# 4        US.
# 5        US.
# 6        US.
# 7        US.
# 8        US.
# 9    Europe.
# 10    Japan.
# 11    Japan.
# 12   Europe.
# 13       US.
# 14       US.
# 15       US.
# 16       US.
# 17    Japan.
# 18       US.
# 19    Japan.
# 20   Europe.
# 21    Japan.
# 22   Europe.
# 23       US.
# 24       US.
# 25    Japan.
# 26    Japan.
# 27    Japan.
# 28       US.
# 29       US.

# %%
finalDf = pd.concat([principalDf, dataf[['brand']]], axis = 1)

# %%
finalDf.head(30)
# Out:
#     PrincipalComponent_1  PrincipalComponent_2     brand
# 0            -124.482385             -5.695018     brand
# 1              99.929554             -3.852403       US.
# 2             196.000234             17.834188   Europe.
# 3            -118.404550              4.662550       US.
# 4             140.289507             25.996358       US.
# 5             152.247166             -5.480252       US.
# 6             254.462769            -30.950839       US.
# 7             -33.183426             18.246173       US.
# 8            -127.666225              3.154447       US.
# 9            -106.931021              1.433536   Europe.
# 10           -114.837865             -9.625730    Japan.
# 11             99.988427             -3.910311    Japan.
# 12            158.366053            -26.726087   Europe.
# 13             11.076468             18.989279       US.
# 14            150.123216             -2.735544       US.
# 15           -130.158954             -1.301075       US.
# 16            105.040391            -12.731866       US.
# 17            -93.712377            -21.199432    Japan.
# 18           -100.972784            -18.383652       US.
# 19           -129.529986             -0.669372    Japan.
# 20            -81.252822            -32.981536   Europe.
# 21            -15.726514             19.811637    Japan.
# 22            147.046872              9.799805   Europe.
# 23           -128.321413              5.069521       US.
# 24           -128.338124             12.033877       US.
# 25           -143.368246             -5.813396    Japan.
# 26            149.030099              4.037210    Japan.
# 27             31.023524             38.252036    Japan.
# 28           -117.737588              2.735895       US.
# 29                   NaN                   NaN       US.

# %%
fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('PCA for Car Dataset', fontsize = 20)


targets = ['Europe', 'US.','Japan']
colors = ['r', 'g', 'b']
for brand, color in zip(targets,colors):
    indicesToKeep = finalDf['brand'] == brand
    ax.scatter(finalDf.loc[indicesToKeep, 'PrincipalComponent_1']
               , finalDf.loc[indicesToKeep, 'PrincipalComponent_2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()
